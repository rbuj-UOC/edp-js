// %% [markdown]
// ![heading_copyright_UOC.png](data:image/png;base64,...)
// # 4.2 JavaScript - Hello World!
//
// * * *

// %%
// Print "Hello World!" on the console
console.log("Hello world!");
// Out:
// Hello world!
