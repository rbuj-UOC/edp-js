// %% [markdown]
// ![heading_copyright_UOC.png](images/heading_copyright_UOC.png)
// #### <div style="text-align: right;"> &#128337;Temps previst de dedicació: 15 minuts</div>
//
// # <font color='#000078'><center>TEMA 2: JavaScript</center></font>
// ## <font color='#000078'><center>Unitat 3: Execució d’un programa</center></font>
//
// Tot i que al material docent directament podrem fer proves d'implementació i execució del nostre codi JS, fonamentalment en aquest curs ens basarem en l'execució del codi a la **consola del navegador web Firefox**.
//
// ### Execució des de la Consola de Firefox
//
// Aquest curs farem molts exercicis, a l'eina Vocareum en trobareu molts, però, per fer proves i implementar el nostre codi, farem servir la consola del navegador web Firefox.
//
// A la introducció de la **Guia de JavaScript de Mozilla** (a l'apartat “**_Cómo empezar con JavaScript_**”) expliquen com s'ha d'executar aquest codi des de la **consola de Firefox**. Tot i això, us deixem aquí una petita explicació de com ho podeu fer:
//
// Obrir aquesta consola és molt senzill, tan sols hem d'entrar a Firefox i, una vegada obert aquest programa anar al [**Menú**] 🡪  [**Més eines**] 🡪 [**Consola del navegador**]:
//
// ![image.png](attachment:image.png)
//
// O directament amb la combinació de tecles **CRTL + MAJÚSCULES + K**.
// Ens apareixerà una nova consola com aquesta:
//
// ![image-2.png](attachment:image-2.png)
//
// Realment el que ens ha aparegut és un **conjunt d'eines** totes orientades a treballar sobre el codi que genera la pàgina en què ens trobem, tot i que nosaltres, de moment, ens centrarem només en la Consola:
//
// ![image-3.png](attachment:image-3.png)
//
// L'avantatge principal de treballar amb la **Consola de Firefox** és que aquesta consola s'executa directament relacionada amb l'HTML del web que estem carregant en el moment que l'emprem, per tant, podrem fer referència i treballar amb elements que tinguem definits a l'HTML actual.
//
// D'altra banda, aquesta consola és una eina que s'ha de conèixer, ja que avui dia, al món professional és molt emprada per depurar codi durant el procés de desenvolupament i joc de proves del programari.
//
// El seu funcionament és molt senzill també: podem executar una ordre en línia, és a dir, escriure una ordre en **_JavaScript_** a una línia i polsar la tecla [**Return**] i automàticament s'executarà:
//
// ![image-6.png](attachment:image-6.png)
//
// D’altra banda, podem definir blocs de codi sencers, emprant **MAJÚSCULES + RETURN** per fer els salts de línia (si no ho fem amb aquesta combinació de tecles se’ns executarà el nostre codi abans d’hora), també podem copiar i enganxar el codi des d’editors de text pla com ara [Notepad++](https://notepad-plus-plus.org/downloads/):
//
// ![image-7.png](attachment:image-7.png)
//
// Proveu-ho als vostres navegadors!.
