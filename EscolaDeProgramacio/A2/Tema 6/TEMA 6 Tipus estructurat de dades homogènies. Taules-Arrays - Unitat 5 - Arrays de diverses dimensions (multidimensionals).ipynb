// %% [markdown]
// ![heading_copyright_UOC.png](images/heading_copyright_UOC.png)
// #### <div style="text-align: right;"> &#128337;Temps previst de dedicació: 15 minuts</div>
//
// # <font color='#000078'><center>TEMA 6: Tipus estructurat de dades homogènies. Taules/Arrays.</center></font>
// ## <font color='#000078'><center>Unitat 5: Arrays de diverses dimensions (multidimensionals)</center></font>
//
// ### Arrays multidimensionals
//
// Fins ara hem treballat amb Arrays d’una sola dimensió, que hem representat com un vector o seqüència. Doncs bé, en algunes situacions ens convindrà treballar amb Arrays de dues dimensions o més, cosa que podem representar com a **matrius**.
//
// #### 🧐 Exemple
//
// > Seguint amb l’exemple inicial, en què s’emmagatzemen les visites diàries
// que rep la pàgina web en un mes, si volem tenir un control de les visites
// rebudes de tot l’any hauríem de fer servir una matriu similar a:
// > ![image.png](attachment:image.png)
// > Com veiem, estem treballant amb un Array de dues dimensions: en un
// eix tindrem els dies que té un mes i a l’altre eix hi representarem els mesos
// de l’any.
// Així doncs, tindrem dos índexs diferents que representaran, cadascun, un
// dels eixos.
// Com representem l’Array bidimensional en JavaScript?: hem vist que en JavaScript un Array pot contenir qualsevol objecte; sí, fins i tot un altre Array.
// Per emmagatzemar les visites rebudes a un web, durant un any en una
// matriu, doncs, podem fer:

// %%
//Defining the annual Array with 12 Arrays of months of 31 days
let annualVisitors1 = Array(12);
let i;
for(i = 0; i < 12; i++){
    //each element of the 12-month Array is a 30-day Array
    annualVisitors1[i] = Array(31);
}
//if we want to assign a total of 360 visits on April 4rd
annualVisitors1[3][4] = 360;
//if we want to access the visits on the third day of the fourth month
console.log(annualVisitors1[3][4]);
// Out:
// 360

// %% [markdown]
// També podríem, si fos el cas, inicialitzar tots els elements d’un Array a zero iterant sobre la seva estructura:

// %%
//Defining the annual Array with 12 Arrays of months of 31 days
let annualVisitors2 = Array(12);
let i;
for(i = 0; i < 12; i++){
    //each element of the 12-month Array is a 30-day Array
    annualVisitors2[i] = Array(31);
}
//we can initialize all elements of the Array to zero
for(i = 0; i < 12; i++){
    for(j = 0; j < 31; j++){
        annualVisitors2[i][j] = 0;
        console.log("POSITION ["+i+"]["+j+"]: "+annualVisitors2[i][j]);
    }
}
// Out:
// POSITION [0][0]: 0
// POSITION [0][1]: 0
// POSITION [0][2]: 0
// POSITION [0][3]: 0
// POSITION [0][4]: 0
// POSITION [0][5]: 0
// POSITION [0][6]: 0
// POSITION [0][7]: 0
// POSITION [0][8]: 0
// POSITION [0][9]: 0
// POSITION [0][10]: 0
// POSITION [0][11]: 0
// POSITION [0][12]: 0
// POSITION [0][13]: 0
// POSITION [0][14]: 0
// POSITION [0][15]: 0
// POSITION [0][16]: 0
// POSITION [0][17]: 0
// POSITION [0][18]: 0
// POSITION [0][19]: 0
// POSITION [0][20]: 0
// POSITION [0][21]: 0
// POSITION [0][22]: 0
// POSITION [0][23]: 0
// POSITION [0][24]: 0
// POSITION [0][25]: 0
// POSITION [0][26]: 0
// POSITION [0][27]: 0
// POSITION [0][28]: 0
// POSITION [0][29]: 0
// POSITION [0][30]: 0
// POSITION [1][0]: 0
// POSITION [1][1]: 0
// POSITION [1][2]: 0
// POSITION [1][3]: 0
// POSITION [1][4]: 0
// POSITION [1][5]: 0
// POSITION [1][6]: 0
// POSITION [1][7]: 0
// POSITION [1][8]: 0
// POSITION [1][9]: 0
// POSITION [1][10]: 0
// POSITION [1][11]: 0
// POSITION [1][12]: 0
// ...
