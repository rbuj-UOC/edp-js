// %% [markdown]
// ![heading_copyright_UOC.png](images/heading_copyright_UOC.png)
// #### <div style="text-align: right;"> &#128337;Temps previst de dedicació: 10 minuts</div>
//
// # <font color='#000078'><center>TEMA 1: Començant a programar</center></font>
// ## <font color='#000078'><center>Unitat 2: Pensament computacional</center></font>
//
// Els ordinadors ens ajuden a resoldre problemes. Però per resoldre un problema primer cal comprendre’l i pensar possibles solucions. En això ens ajuda aplicar el **pensament computacional**, que ens permet primer entendre un problema complex i, després, solucionar-lo pas a pas de manera prou clara i concisa perquè ho pugui entendre algú altre i també un ordinador.
// Es fonamenta en quatre tècniques, bàsicament. Totes quatre ajuden a gestionar la complexitat dels problemes:
//
// | |   |  |
// |---:|:-------------|:-------------|
// | 1 | Descomposició  |  Dividir un problema complicat, que no sabem resoldre directament, en parts més petites i més fàcilment solucionables. |
// | 2 | Reconeixement  de patrons  | Buscar similituds entre diferents problemes per aprofitar el que se sap per solucionar-ne un per aplicar-ho a l’altre. |
// | 3 | Abstracció  | Simplificar, ignorant els detalls innecessaris per quedar-nos amb l’essència i fixar-nos només en allò és rellevant en relació amb el problema. |
// | 4 | Algorísmica  | Dissenyar els passos un a un per solucionar un problema. Per molt màgic que pugui semblar, tot el que vulguem que faci un ordinador es pot escriure a partir d’unes instruccions concretes i senzilles que es combinen entre si en forma de seqüència, repetició i selecció. |
//
// Tenir destresa en aquestes tècniques ajuda a programar perquè facilita dividir un problema complex en un seguit de problemes més senzills i gestionables (descomposció) que es poden anar resolent un a un individualment, tenint en compte com s’han solucionat problemes similars abans (reconeixement de patrons) i centrant-nos només en els detalls rellevants del problema (abstracció). Tot seguit, es pot definir el pla d’acció, entès com a passos a seguir per resoldre cadascun dels problemes (fer l’algorisme). Finalment, aquests passos seran l’esquema de base per codificar el programa en un llenguatge de programació concret amb què un ordinador resoldrà el problema.
//
// ![image.png](attachment:image.png)
