// %% [markdown]
// ![heading_copyright_UOC.png](images/heading_copyright_UOC.png)
// #### <div style="text-align: right;"> &#128337;Temps previst de dedicació: 15 minuts</div>
//
// # <font color='#000078'><center>TEMA 8: Esquemes algorísmics. Recorregut i cerca d’una seqüència.</center></font>
// ## <font color='#000078'><center>Unitat 1: Patrons i seqüències</center></font>
//
// ### Patrons i seqüències
//
// 1. **PATRÓ**
//
// Per ser un bon programador, cal saber identificar **patrons**.
//
// > Un patró vindria a ser el que es detecta quan una cosa es repeteix una vegada i una altra de la mateixa manera, com ara el patró cíclic en què s’organitza el temps en una agenda; mesos, setmanes, dies i hores.
//
// El reconeixement de patrons aplicat a la resolució de problemes ens permet buscar semblances entre diversos problemes, per així poder aprofitar el que sabem sobre com solucionar-ne un per aplicar-ho a la solució d’un altre que sigui similar. En el cas del codi, detectar patrons ens fa guanyar molta eficiència i eficàcia, és per això que són molt importants.
//
// Ja coneixem la sintaxi bàsica de Javascript, així doncs, amb les tres estructures (seqüencial, condicional i iterativa), i els tipus bàsics i estructurats de dades podem planificar com trobar la solució a qualsevol problema que es pugui resoldre amb un ordinador. No ens cal res més. Però podem procedir de manera més sistemàtica i eficient si fem servir, per exemple, **patrons**.
//
// 1. **SEQÜÈNCIA DE DADES**
//
// Una **seqüència de dades** és una successió d’elements ordenats d’una manera determinada.
//
// Una seqüència pot ser de diferents tipus de dades i sempre té un final (és finita).
//
// Entendre el concepte de *seqüència de dades* és important, ja que gran part dels programes mínimament complexos consisteixen a repetir un conjunt de càlculs (un patró) en una seqüència de dades.
//
// > Una de les estructures de dades que més bé representa les seqüències és l’**Array** (*taula* en termes algorísmics).
//
// Un cas molt habitual de patró que es repeteix quan tractem problemes que treballen amb seqüències de dades és el recorregut. **Fer un recorregut** vol dir passar per tots els elements de la seqüència un darrere l’altre. Un altre patró molt comú és la cerca, que consisteix a buscar un element determinat en una seqüència d’elements.
//
// #### 🧐 Exemple
//
// > Imaginem que volem treballar amb els alumnes d’una classe que definirem com objectes literals de JavaScript i que tindran les propietats següents: nom, cognoms, any de naixement, nota mitjana i si ha repetit el curs o no.
// >
// > Doncs podem, emprant una seqüència de dades que, traduït en termes de JavaScript, no és més que un Array, emmagatzemar aquests alumnes seqüencialment, un darrere de l’altre en cadascuna de les posicions de l’Array, de manera que tindríem:

// %%
//Declaring the Array that represents the students in the classroom:
let classroomStudents = new Array();
//Pushing students on the classroom: 
//First
classroomStudents.push ({ 
    name: "Carme", 
    surname: "Ibáñez Marchena", 
    yearOfBirth: 1998, 
    averageGrade: 8.3,
    repeater: false
});
//Second
classroomStudents.push ({ 
    name: "Joan", 
    surname: "Espí Prats", 
    yearOfBirth: 1999, 
    averageGrade: 7.8,
    repeater: true
});
//Third
classroomStudents.push ({ 
    name: "Maria", 
    surname: "Massats Perelló", 
    yearOfBirth: 2003, 
    averageGrade: 4.5,
    repeater: false
});
//Fourth
classroomStudents.push ({ 
    name: "Ramon", 
    surname: "Cugat Llopis", 
    yearOfBirth: 2000, 
    averageGrade: 5.7,
    repeater: true
});
//Fifth
classroomStudents.push ({ 
    name: "Anna", 
    surname: "Bernal Valls", 
    yearOfBirth: 2002, 
    averageGrade: 3.5,
    repeater: false
});
console.log(classroomStudents);
// Out:
// [ { name: 'Carme',
//     surname: 'Ibáñez Marchena',
//     yearOfBirth: 1998,
//     averageGrade: 8.3,
//     repeater: false },
//   { name: 'Joan',
//     surname: 'Espí Prats',
//     yearOfBirth: 1999,
//     averageGrade: 7.8,
//     repeater: true },
//   { name: 'Maria',
//     surname: 'Massats Perelló',
//     yearOfBirth: 2003,
//     averageGrade: 4.5,
//     repeater: false },
//   { name: 'Ramon',
//     surname: 'Cugat Llopis',
//     yearOfBirth: 2000,
//     averageGrade: 5.7,
//     repeater: true },
//   { name: 'Anna',
//     surname: 'Bernal Valls',
//     yearOfBirth: 2002,
//     averageGrade: 3.5,
//     repeater: false } ]

// %% [markdown]
// > Això ens permetrà més endavant poder-los recórrer i accedir a aquests objectes emmagatzemats seqüencialment a l’Array (taula) per fer una sèrie de cerques o, simplement, per mostrar-los tots.
